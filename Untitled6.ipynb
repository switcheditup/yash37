# %%
#datacleaning and processing
import pandas as pd

# %%
f=pd.read_csv("Employee.csv")

# %%
f.head()
# Out:
#    Id      Name  Age Salary
# 0   1  kendrick   23  66666
# 1   2     vishu   34    Nan
# 2   3     gullu   56  99999
# 3   4       ron   34  99999
# 4   5    yogesh   33  88888

# %%
#next we identify values

# %%
print(f.isnull().sum())
# Out:
# Id        0
# Name      0
# Age       0
# Salary    0
# dtype: int64

# %%
#then we handle the missing values

# %%
f['Salary'] = pd.to_numeric(f['Salary'], errors='coerce')
f['Salary'].fillna(f['Salary'].mean(),inplace=True)
# Out:
# <ipython-input-21-74f8c23df22a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   f['Salary'].fillna(f['Salary'].mean(),inplace=True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 f['Salary'] = pd.to_numeric(f['Salary'], errors='coerce')
#       2 f['Salary'].fillna(f['Salary'].mean(),inplace=True)
# ----> 3 e.head()
#
# NameError: name 'e' is not defined

# %%
f.head()
# Out:
#    Id      Name  Age   Salary
# 0   1  kendrick   23  66666.0
# 1   2     vishu   34  88888.0
# 2   3     gullu   56  99999.0
# 3   4       ron   34  99999.0
# 4   5    yogesh   33  88888.0

# %%
f.drop(columns=['Id'],inplace=True)

# %%
f.head()
# Out:
#        Name  Age   Salary
# 0  kendrick   23  66666.0
# 1     vishu   34  88888.0
# 2     gullu   56  99999.0
# 3       ron   34  99999.0
# 4    yogesh   33  88888.0

# %%
#detect outliers using IQR
#formula Q3 - Q1 
#outliers

Q1=f['Salary'].quantile(0.25)

Q3=f['Salary'].quantile(0.75)

IQR= Q3 - Q1

# %% [raw]
# print (e['out'])
